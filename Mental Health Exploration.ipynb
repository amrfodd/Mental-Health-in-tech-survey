# %%
import dabl

# %%
from pandas import read_csv
# load dataset
url = 'mental.csv'
mental = read_csv(url, index_col = 0)
# split into input and output elements
mental.head()
# Out:
#     Age Gender        Country self_employed family_history treatment  \
# 18   46   male  United States           Yes            Yes        No
# 20   29   male  United States            No            Yes       Yes
# 21   31   male  United States           Yes             No        No
# 22   46   male  United States            No             No       Yes
# 23   41   male  United States            No             No       Yes
#
#    work_interfere    no_employees remote_work tech_company  ...   anonymity  \
# 18      Sometimes             1-5         Yes          Yes  ...         Yes
# 20      Sometimes         100-500          No          Yes  ...          No
# 21          Never             1-5         Yes          Yes  ...         Yes
# 22          Often          26-100         Yes          Yes  ...  Don't know
# 23          Never  More than 1000          No           No  ...  Don't know
#
#                  leave mental_health_consequence phys_health_consequence  \
# ...

# %%
dabl.clean(mental, verbose = 2).head(2)
# Out:
# Detected feature types:
# continuous       1
# dirty_float      0
# low_card_int     0
# categorical     23
# date             0
# free_string      0
# useless          0
# dtype: int64
#     Age Gender        Country self_employed family_history treatment  \
# 18   46   male  United States           Yes            Yes        No
# 20   29   male  United States            No            Yes       Yes
#
#    work_interfere no_employees remote_work tech_company  ... anonymity  \
# 18      Sometimes          1-5         Yes          Yes  ...       Yes
# 20      Sometimes      100-500          No          Yes  ...        No
#
#                  leave mental_health_consequence phys_health_consequence  \
# 18           Very easy                        No                      No
# 20  Somewhat difficult                     Maybe                      No
#
#        coworkers    supervisor mental_health_interview phys_health_interview  \
# ...

# %% [markdown]
# # EDA with quickda

# %%
import quickda as eda
from quickda.explore_data import *
from quickda.clean_data import *
from quickda.explore_numeric import *
from quickda.explore_categoric import *
from quickda.explore_numeric_categoric import *
from quickda.explore_time_series import *

# %%
explore(mental)
# Out:
#                            dtypes  count  null_sum  null_pct  nunique  \
# Age                         int64    973         0       0.0       46
# Country                    object    973         0       0.0       39
# Gender                     object    973         0       0.0        3
# anonymity                  object    973         0       0.0        3
# benefits                   object    973         0       0.0        3
# care_options               object    973         0       0.0        3
# coworkers                  object    973         0       0.0        3
# family_history             object    973         0       0.0        2
# leave                      object    973         0       0.0        5
# mental_health_consequence  object    973         0       0.0        3
# mental_health_interview    object    973         0       0.0        3
# mental_vs_physical         object    973         0       0.0        3
# ...

# %%
# Summarize dataset
explore(mental, method = 'profile', report_name = 'load dataset report')
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated with the `pandas-profiling` Python package&quot;&gt;&lt;meta name=author content=&quot;Simon Brugman and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling v2.10.0&quot;&gt;&lt;meta name=url content=https://github.com/pandas-profiling/pandas-profiling&gt;&lt;meta name=date content=&quot;2021-09-22 10:27:37.423302&quot;&gt;&lt;title&gt;load dataset report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...

# %% [markdown]
# # Visualize with quickda

# %%
eda_num(mental)
# Out:
# Outlier Analysis - Boxplot
# Distribution Analysis - Histogram

# %%
# Correlation matrix
eda_num(mental, method = 'correlation')
# Out:
# Correlation Analysis - Heatmap
# <style  type="text/css" >
#     #T_dfcec2d1_1b8f_11ec_9768_784561c24782row0_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }</style><table id="T_dfcec2d1_1b8f_11ec_9768_784561c24782" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Age</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_dfcec2d1_1b8f_11ec_9768_784561c24782level0_row0" class="row_heading level0 row0" >Age</th>
#                         <td id="T_dfcec2d1_1b8f_11ec_9768_784561c24782row0_col0" class="data row0 col0" >1.00</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# # Visualization

# %%
import sweetviz as sv

# %%
my_report = sv.analyze(mental)
# Out:
#                                              |          | [  0%]   00:00 -> (? left)

# %%
my_report.show_html()
# Out:
# Report SWEETVIZ_REPORT.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.
